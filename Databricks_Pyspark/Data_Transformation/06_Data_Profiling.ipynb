# %%
# %sql
select * from project_etl.bronze.v_customers
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
# display(
#   spark.sql(
#     """
#     select * from project_etl.bronze.v_customers
#     """
#   )
# )
df = spark.table("project_etl.bronze.v_customers")
display(
  df.describe()
)
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
# %sql
select count(*), count(customer_id),count(email) from project_etl.bronze.v_customers;

# %%
# %sql
select count(*), count_if(customer_id is null),count_if(email is not null) from project_etl.bronze.v_customers

# %%
# %sql
SELECT DISTINCT customer_name
FROM project_etl.bronze.v_customers
