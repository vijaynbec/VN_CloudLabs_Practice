-- %%
list '/Volumes/project_etl/landing/opertaional/customer_streams/'

-- %%
CREATE OR REPLACE TEMPORARY VIEW customer_json
USING json
OPTIONS (
  path '/Volumes/project_etl/landing/opertaional/customer_streams/customer_2025_01m.json',
  schema '
    customer_id INT,
    customer_name STRING,
    date_of_birth DATE,
    email STRING,
    phone STRING,
    city STRING,
    member_since DATE,
    created_timestamp TIMESTAMP '
  
);

SELECT * FROM customer_json LIMIT 20;
