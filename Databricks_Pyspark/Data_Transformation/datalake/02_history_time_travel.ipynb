# %% [markdown]
# History and Timne Travel and Restore
# - Table History
# - Query from specific time
# - Restore from a version

# %%
# %sql
desc history project_etl.delta_lake.table_lake;

# %%
# %sql
-- select * from project_etl.delta_lake.table_lake;  -- return 3 rows - latest version
-- select * from project_etl.delta_lake.table_lake version as of 1  ---### resturn one row
-- select * from project_etl.delta_lake.table_lake version as of 2  -- return 3 roaws
select * from project_etl.delta_lake.table_lake version as of 0 -- Just a empty return from table

# %%
# %sql
select * from project_etl.delta_lake.table_lake timestamp as of '2025-11-07T20:58:59.000+00:00';

# %%
# %sql
-- restore table project_etl.delta_lake.table_lake version as of 1;  -- restore to version 1
-- describe history project_etl.delta_lake.table_lake; -- list the vesrion
-- select * from project_etl.delta_lake.table_lake  -- return one row
-- restore table project_etl.delta_lake.table_lake version as of 2; 
select * from project_etl.delta_lake.table_lake  -- return 3 rows
