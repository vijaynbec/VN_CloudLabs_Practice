# %%
# %sql
create schema if not exists project_etl.delta_lake
managed location 's3://data-databricks-sample-102426687040/delta_lake/';

# %%
# %sql
drop table if exists project_etl.delta_lake.table_lake;
create table if not exists project_etl.delta_lake.table_lake
( name string,
  country string
)

# %%
# %sql
desc extended project_etl.delta_lake.table_lake

# %%
# %sql
insert into project_etl.delta_lake.table_lake
values ('Trump', 'US')

# %%
# %sql
select * from project_etl.delta_lake.table_lake

# %%
# %sql
insert into project_etl.delta_lake.table_lake
values ('Modi', 'IN'),("Putin", "RU")
