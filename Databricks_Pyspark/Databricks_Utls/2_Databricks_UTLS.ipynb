# %% [markdown]
# # Utilities
# - File System
# - Secret
# - Widget
# - Notebook Workflow

# %%
# %fs
ls /

# %%
dbutils.fs.ls('/databricks-datasets')

# %%
display(dbutils.fs.ls('/databricks-datasets/'))
# dbfs:/databricks-datasets/amazon/test4K/part-r-00000-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet
# df = (
#     spark.read
#     .option('header', True)
#     .option('inferSchema', True)
#     .csv('dbfs:/databricks-datasets/amazon/test4K/part-r-00000-64a9bd4a-25fc-48e6-8a60-2fd057bddd27.gz.parquet')
# )
# display(df)

# %%
##dbutils.help();   # first level of help
##dbutils.fs.help()  # first/second level of help
dbutils.fs.help('cp')  # first/second/third level of help

# %%
files = dbutils.fs.ls('/databricks-datasets')
filtered_files = [
    f.path for f in files
    if f.path.endswith('.json') or f.path.endswith('.csv') or f.path.endswith('.parquet')
]
display(filtered_files)
