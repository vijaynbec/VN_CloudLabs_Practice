# %% [markdown]
# # Notebook Introduction and Usage
# - %md - for Notes
# - %py - for Python code
# - %sql - for SQL code
# - %python,%sql,%scala,%r - switch to different languages
# - %fs - run file system
# - %sh - Run shell commands
# - %pip - Install pip libraries
# - %run - includ another notbook in main notebook

# %%
# %sql
SELECT ("Hi from SQL")

# %%
print ("Hello from Python")

# %%
# %fs
ls /databricks-datasets/airlines/part-00000

# %%
# %sh ps

# %%
# %pip list

# %%
# %run "/Workspace/Databricks_Utls/2_1 Subnotebook_calledin_1"
