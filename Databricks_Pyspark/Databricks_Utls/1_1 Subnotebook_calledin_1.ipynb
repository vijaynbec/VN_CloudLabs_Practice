# %%
env = 'dev'

# %%
import os
import platform
def print_env_info():
    # print python version
    print(f"Python {platform.python_version()}")
    # print spark version
    print(f"Spark {spark.version}")
    # databricks version
    print(f"Databricks {os.environ['DATABRICKS_RUNTIME_VERSION']}")
print_env_info()
