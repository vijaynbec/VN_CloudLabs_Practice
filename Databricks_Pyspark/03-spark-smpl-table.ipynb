-- %%
create database if not exists ssampledb;

-- Create table in Unity Catalog
create table if not exists sampledb.country (
    StateCode string,
    StateName string,
    CountryCode string,
    CountryName string
);

-- Insert data into the table using a temporary table created in a previous step
insert into sampledb.country
--select * from TempView.country_df_table
--select * from global_temp.country_df_table;
-- Select data from the table
-- select * from sample_catalog.sampledb.country;
-- Optional: Truncate the table after validation
--truncate table sample_catalog.sampledb.country;
