-- %%
CREATE SCHEMA IF NOT EXISTS fivetran_aws.silver;
CREATE SCHEMA IF NOT EXISTS fivetran_aws.gold;
CREATE SCHEMA IF NOT EXISTS fivetran_aws.fivetran_source;

-- -- Drop the table - if exist
-- DROP TABLE IF EXISTS fivetran_aws.fivetran_source.customers;
-- DROP TABLE IF EXISTS fivetran_aws.gold.customers;
-- DROP TABLE IF EXISTS fivetran_aws.silver.customers;
-- check the source file
SHOW TABLES FROM personal_vijay.fivetran_aws_s3;
